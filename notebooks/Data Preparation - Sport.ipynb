# %% [markdown]
# # Load files from data
#
# **load all the articles from local storage (new_data & data) and prepare the tables for the subsequent analysis. ALternatively - if implemented - use boto3 to load data from S3 storage on AWS:**

# %% [markdown]
# ---

# %% [markdown]
# ### Loading packages

# %%
import pandas as pd
import numpy as np
import glob
import re
import string
#import boto3

# %% [markdown]
# ## Loading data
#
# The for-loop gathers all the .csv files within the data directory, concats and labels them and then returns a data frame.

# %%
category = {
    1: 'politik', 2: 'wirtschaft', 3: 'finanzen', 4: 'feuilleton', 5: 'sport', 6: 'gesellschaft', 7: 'stil', 
    8: 'technik-motor', 9: 'wissen', 10: 'reise', 11: 'beruf-chance', 12: 'aktuell'
}

# %%
def build_tables(category):
    raw_articles = []
    if category is 'aktuell':
        path = f"../new_data/aktuell/"
    else:
        path = f"../new_data/{category}/"
        
    all_files = glob.glob(path + '*.csv')

    for filename in all_files:
        df = pd.read_csv(filename, index_col=None, header=0)
        raw_articles.append(df)
    faz_articles = pd.concat(raw_articles, axis=0, ignore_index=True)
    faz_articles['label'] = category

    return faz_articles

# %% [markdown]
# ---
# # Generate Test and Train Data
#
# **This for-loop goes through the data frames built in the first step and then collects the words from each entry in a list.**
#
# ## Train Data:

# %%
frames = []

for key, value in category.items():
    raw_faz = build_tables(value)
    frames.append(raw_faz)
    faz_train = pd.concat(frames, axis=0, ignore_index=True)

# %%
faz_train = faz_train.drop_duplicates()

# %%
faz_train.groupby('label').count()
# Out:
#                link  published  title  detailed
# label
# aktuell         441        441    441       441
# beruf-chance     14         14     14        14
# feuilleton       69         69     69        69
# finanzen         45         45     45        45
# gesellschaft     79         79     79        79
# politik         170        170    170       170
# reise             9          9      9         9
# sport           146        146    146       146
# stil             18         18     18        18
# technik-motor    24         24     24        24
# wirtschaft       95         95     95        95
# wissen           26         26     26        26

# %% [markdown]
# # Split train data in 'sport' and 'rest':
#
# This step is for the sake of labelling the subsequant data and to get an idea of the data distribution (**'Politics' make up about 17% of the train data**):

# %%
faz_rest = faz_train[faz_train.label != 'sport']
faz_rest.count()
# Out:
# link         990
# published    990
# title        990
# detailed     990
# label        990
# dtype: int64

# %%
faz_sport = faz_train[faz_train.label == 'sport']
faz_sport.count()
# Out:
# link         146
# published    146
# title        146
# detailed     146
# label        146
# dtype: int64

# %%
170/966
# Out:
# 0.17598343685300208

# %% [markdown]
# ---

# %% [markdown]
# ## Build feature word list:

# %%
rgx_singles = re.compile("([\w][\w']*[\w])")
rgx_doubles = re.compile("([\w][\w']*[\w] +[\w][\w']*[\w])")
rgx_triples = re.compile("([\w][\w']*[\w] +[\w][\w']*[\w] +[\w][\w']*[\w])")

translator = str.maketrans('', '', string.punctuation)

# %%
words = []

for index, row in faz_train.iterrows():
    line = row['detailed'].translate(translator) 
    words += rgx_singles.findall(line)
    words += rgx_doubles.findall(line)
    words += rgx_triples.findall(line)

# %%
word_list = pd.DataFrame(words, columns=['word'])

# %%
titles = []

for index, row in faz_train.iterrows():
    line = row['title'].translate(translator) 
    titles += rgx_singles.findall(line)
    titles += rgx_doubles.findall(line)
    titles += rgx_triples.findall(line)

# %%
title_list = pd.DataFrame(titles, columns=['word'])

# %%
scraped = [word_list, title_list]
merged = pd.concat(scraped)

# %%
merged['count'] = 1

# %%
features = merged.groupby('word').count()

# %%
features = features.sort_values('count', ascending=False)
feature_list = features.head(400)
feature_list = list(feature_list.index)

# %%
feature_list
# Out:
# ['der',
#  'in',
#  'die',
#  'und',
#  'im',
#  'den',
#  'für',
#  'von',
#  'auf',
#  'das',
#  'mit',
#  'Die',
#  'ist',
#  'dem',
#  'sich',
#  'eine',
#  'ein',
#  'nicht',
#  'des',
#  'aus',
#  'nach',
#  'an',
#  'gegen',
#  'zu',
#  'hat',
#  'als',
#  'es',
#  'Der',
#  'vor',
#  'am',
#  'bei',
#  'Das',
#  'einem',
#  'einer',
#  'noch',
#  'einen',
#  'will',
#  'über',
#  'um',
#  'auch',
#  'er',
#  'sie',
#  'wird',
#  'Ein',
#  'sind',
#  'mehr',
#  'zum',
#  'werden',
#  'haben',
#  'wie',
#  'Doch',
#  'nur',
#  'zur',
#  'muss',
#  'in der',
#  'war',
#  'beim',
#  'Sie',
#  'seine',
#  'sein',
#  'gibt',
#  'In',
#  'aber',
#  'soll',
#  'seiner',
#  'nun',
#  'dass',
#  'schon',
#  'Nowitzki',
#  'Bayern',
#  'Trainer',
#  'Jahre',
#  'was',
#  'wenn',
#  'Trump',
#  'ihre',
#  'Berlin',
#  'ab',
#  'kann',
#  'geht',
#  'so',
#  'Eine',
#  'wieder',
#  'unter',
#  'Wie',
#  'Brexit',
#  'neuen',
#  'immer',
#  'gut',
#  'viel',
#  'keine',
#  'vom',
#  'Jahren',
#  'Dirk',
#  'ins',
#  'Liveticker',
#  'Netanjahu',
#  'FC',
#  'eines',
#  'Bundesliga',
#  'Es',
#  'neue',
#  'Nun',
#  'deutschen',
#  'Im',
#  'Präsident',
#  'Deutschland',
#  'Weg',
#  'wegen',
#  'ihren',
#  'EU',
#  'wurde',
#  'Und',
#  'ihr',
#  'Donald',
#  'AfD',
#  'Ende',
#  'Dortmund',
#  'macht',
#  'Partei',
#  'doch',
#  'links',
#  'müssen',
#  'Nach',
#  'wollen',
#  'Welt',
#  'Kinder',
#  'Was',
#  'Euro',
#  'seinen',
#  'Mit',
#  'für die',
#  'allem',
#  'zwei',
#  'League',
#  'auf dem',
#  'Spiel',
#  'Er',
#  'Auch',
#  'deutsche',
#  'ohne',
#  'ihrer',
#  'Merkel',
#  'man',
#  'steht',
#  'oder',
#  'gehen',
#  'Menschen',
#  'May',
#  'dieser',
#  'zurück',
#  'Boeing',
#  'Ich',
#  'bis',
#  'Zeit',
#  'weiter',
#  'Jahr',
#  'NBA',
#  '50',
#  'fordert',
#  'Deutsche',
#  'Champions',
#  'seit',
#  'lässt',
#  'München',
#  'können',
#  'durch',
#  'spricht',
#  'Premierministerin',
#  'einmal',
#  'zwischen',
#  'andere',
#  'große',
#  'zeigt',
#  'Benjamin',
#  'britische',
#  'jetzt',
#  'Regierung',
#  'viele',
#  'März',
#  'wohl',
#  'könnte',
#  'Interview',
#  'kommt',
#  'Israel',
#  'Vor',
#  'Frankfurt',
#  'besten',
#  'Opfer',
#  'Stadt',
#  'Für',
#  'sieht',
#  'in die',
#  'Theresa',
#  'Bremen',
#  'Trumps',
#  'Geld',
#  'ihm',
#  'hatte',
#  'machen',
#  'und die',
#  'Mann',
#  'Grenze',
#  'Wer',
#  'ich',
#  'lange',
#  'Wahl',
#  'Amerika',
#  'sagt',
#  'London',
#  'nach dem',
#  'Unternehmen',
#  'führt',
#  'deutlich',
#  'Augsburg',
#  'bald',
#  'Migranten',
#  'Millionen',
#  'Polizei',
#  'Bild',
#  'Staatsanwalt',
#  'weniger',
#  'Dirk Nowitzki',
#  'diesem',
#  'für den',
#  'Warum',
#  'großen',
#  'seinem',
#  'beendet',
#  'ist ein',
#  'lassen',
#  'sehr',
#  'Deutschen',
#  'bei der',
#  'hier',
#  'Montag',
#  'Jetzt',
#  'Dabei',
#  'Aber',
#  'offenbar',
#  'dann',
#  'Altmaier',
#  '2019',
#  'kaum',
#  'Verfolgen',
#  'Hannover',
#  'verliert',
#  'mit dem',
#  'kommen',
#  'Topspiel',
#  'etwas',
#  'So',
#  'heute',
#  'gewinnt',
#  'Stuttgart',
#  'Angela',
#  'im Liveticker',
#  'Frankfurter',
#  'amerikanischen',
#  'sagen',
#  'alten',
#  'drei',
#  'läuft',
#  'Opposition',
#  'Union',
#  'Samstag',
#  'Kritik',
#  'Karriere',
#  'dafür',
#  'erklärt',
#  'Staaten',
#  'Woche',
#  'aus der',
#  'Druck',
#  'Tag',
#  'Frau',
#  'setzt',
#  'an der',
#  'alles',
#  'liegt',
#  'letzten',
#  'Freitag',
#  'Markus',
#  'Bei',
#  'denn',
#  'Debatte',
#  'Europa',
#  'Gantz',
#  'vier',
#  'Klopp',
#  'April',
#  'worden',
#  'mit einem',
#  'Gladbach',
#  '21',
#  'Nielsen',
#  'Auf',
#  'Schon',
#  'Ministerpräsident',
#  'ihrem',
#  'diese',
#  'stellt',
#  'diskutiert',
#  'wirklich',
#  'Dafür',
#  'amerikanische',
#  'Thomas',
#  'Parlament',
#  'Abgang',
#  'erste',
#  'ersten',
#  'neuer',
#  'aus dem',
#  'genug',
#  'Borussia',
#  'sollte',
#  'kein',
#  'Prozent',
#  'Verfolgen Sie',
#  'Soldaten',
#  'sollen',
#  'Champions League',
#  'Kampf',
#  'alte',
#  'Schalke',
#  'Hauptstadt',
#  'bin',
#  'Liverpool',
#  'Israels',
#  'Spiele',
#  'Pressekonferenz',
#  'bei einem',
#  'Will',
#  'Frankreich',
#  'britischen',
#  'ihn',
#  'hält',
#  'Platz',
#  '11',
#  'über den',
#  'bekannt',
#  'dort',
#  'danach',
#  'Bundesliga im Liveticker',
#  'fast',
#  'Bundesliga im',
#  'verlassen',
#  'Köln',
#  'Familie',
#  'Paris',
#  'leben',
#  'Assistent',
#  'Leverkusen',
#  'droht',
#  'Dortmunder',
#  'Leipzig',
#  'Max',
#  'trifft',
#  'Martin',
#  'dazu',
#  'selbst',
#  '20',
#  'Briten',
#  'Anne',
#  'mit der',
#  'frühere',
#  'Donald Trump',
#  'steigen',
#  'Future',
#  'anderen',
#  'ganz',
#  'stehen',
#  'Fälle',
#  'BasketballStar',
#  'Fridays',
#  'Premierministerin Theresa',
#  'heißt',
#  'Land',
#  'sei',
#  'Posten',
#  'dabei',
#  'Schmidt',
#  'Vereinigten',
#  'auf die',
#  'beide',
#  'Glück',
#  'Scheuer',
#  'Tor',
#  'alle',
#  'wir',
#  'Nicht',
#  'Präsidenten',
#  'habe',
#  'sehen',
#  'Haus',
#  'vor allem',
#  'vorgestellt',
#  'zahlen',
#  'der NBA',
#  'liegen']

# %%
dictionary={}

for i in range(len(feature_list)):
    dictionary[feature_list[i]] = i

# %% [markdown]
# # Iterate over 'sport' buzzwords:

# %%
sport_buzzword = []

for index, row in faz_sport.iterrows():
    new_line = np.zeros(400)
    words = list(row['detailed'].split(' '))
    for word in words:
        if word in dictionary:
            new_line[dictionary[word]] += 1
    sport_buzzword.append(new_line)

# %%
df1 = pd.DataFrame(sport_buzzword, columns=feature_list)

# %%
df1['goal_val'] = 1

# %% [markdown]
# # Iterate over remaining buzzwords:

# %%
buzzwords = []

for index, row in faz_rest.iterrows():
    new_line = np.zeros(400)
    words = list(row['detailed'].split(' '))
    for word in words:
        if word in dictionary:
            new_line[dictionary[word]] += 1
    buzzwords.append(new_line)

# %%
df2 = pd.DataFrame(buzzwords, columns=feature_list)

# %%
df2['goal_val'] = 0

# %%
train_tables = [df1, df2]
top_train_data = pd.concat(train_tables)

# %% [markdown]
# ---
# **saving the train data frames to a .csv file:**

# %%
name = 'train_data'

path = "../data_frames/sport/" + name
print("Pathname:", path)
# Out:
# Pathname: ../data_frames/sport/train_data

# %%
top_train_data.to_csv(path, index=False)

# %% [markdown]
# # SAME FOR TEST DATA:

# %%
def build_test_tables(category):
    raw_article = []
    if category is 'aktuell':
        path = f"../data/aktuell/"
    else:
        path = f"../data/{category}/"
        
    all_files = glob.glob(path + '*.csv')

    for filename in all_files:
        df = pd.read_csv(filename, index_col=None, header=0)
        raw_article.append(df)
    faz_article = pd.concat(raw_article, axis=0, ignore_index=True)
    faz_article['label'] = category

    return faz_article

# %%
fram = []

for key, value in category.items():
    raw = build_test_tables(value)
    fram.append(raw)
    faz_test = pd.concat(fram, axis=0, ignore_index=True)

# %%
faz_test = faz_test.drop_duplicates()

# %%
faz_test
# Out:
#                                                    link  \
# 0     https://www.faz.net/aktuell/politik/trumps-pra...
# 1     https://www.faz.net/aktuell/brexit/nach-brexit...
# 2     https://www.faz.net/aktuell/politik/ausland/eu...
# 3     https://www.faz.net/aktuell/politik/ausland/ve...
# 4     https://www.faz.net/aktuell/politik/alle-alter...
# 5     https://www.faz.net/aktuell/politik/ausland/na...
# 6     https://www.faz.net/aktuell/politik/ausland/sc...
# 7     https://www.faz.net/aktuell/politik/ausland/sp...
# 8     https://www.faz.net/aktuell/politik/inland/meh...
# 9     https://www.faz.net/aktuell/politik/inland/wah...
# 10    https://www.faz.net/aktuell/gesellschaft/krimi...
# 11    http://blogs.faz.net/einspruch/2019/04/03/sond...
# 2082  Ghosn ist in Tokio mehrerer Vergehen angeklagt...  aktuell
# 2083  Blick auf die Altstadt von LuzernDie Schweizer...  aktuell
# 2084  Ryanair ist unter den 10 größten CO2-Emittente...  aktuell
# 2086  Frauke Petry mit ihrem Anwalt Carsten Brunzel ...  aktuell
# 2087  Ein Brexit-Gegner spaziert in Westminister an ...  aktuell
# 2088  Enders hinterlässt sein Unternehmen in gutem Z...  aktuell
# 2089  Geduld gefordert: An den Sicherheitsschleusen ...  aktuell
# 2090  Suzuki Swift SportAls Sportmodell mit 140 PS s...  aktuell
# 2093  Gesundheitsgefährdend: Vielerorts wird Gold pe...  aktuell
# 2094  Ein Mädchen legt seinen Kopf auf den Tisch.Red...  aktuell
# 2102  Nach einer Amokdrohung ist an einer Flensburge...  aktuell
# 2108  EU-Kommissionspräsident Jean-Claude Juncker am...  aktuell
# 2121  EU-Kommissionspräsident Jean-Claude Juncker am...  aktuell
# 2137  Schließt eine Mathe-Schwäche ein Ingenieurstud...  aktuell
# 2146  Theresa May setzt mit ihren Gesprächen mit der...  aktuell
# 2147  Franz Müntefering und der damalige Bundeskanzl...  aktuell
# 2151  Mitglieder des Künstlerkollektivs ZPS stehen i...  aktuell
# 2152  Stefan Horngacher in seiner Funktion als Train...  aktuell
# 2154  Beim Ballspielen brach sich ein junger Hund de...  aktuell
# 2157  Vize-Kommissionspräsident Frans Timmermans am ...  aktuell
# 2160  Labour-Chef Jeremy Corbyn (Mitte), Schattenbre...  aktuell
# 2161  Lewandowski (links), Kimmich und die Bayern ge...  aktuell
# 2164  59112307Der HSV, Leipzig und die Bayern stehen...  aktuell
# 2167  Besucher in der Kuppel des Reichstagsgebäudes ...  aktuell
#
# [469 rows x 5 columns]

# %% [markdown]
# ---

# %%
test_sport = faz_test[faz_test.label == 'sport']
test_sport.count()
# Out:
# link         36
# published    36
# title        36
# detailed     36
# label        36
# dtype: int64

# %%
test_rest = faz_test[faz_test.label != 'sport']
test_rest.count()
# Out:
# link         433
# published    433
# title        433
# detailed     433
# label        433
# dtype: int64

# %%
66/403
# Out:
# 0.16377171215880892

# %%
test_sport_buzzword = []

for index, row in test_sport.iterrows():
    new_line = np.zeros(400)
    words = list(row['detailed'].split(' '))
    for word in words:
        if word in dictionary:
            new_line[dictionary[word]] += 1
    test_sport_buzzword.append(new_line)

# %%
df3 = pd.DataFrame(test_sport_buzzword, columns=feature_list)

# %%
df3['goal_val'] = 1

# %%
test_rest_buzzword = []

for index, row in test_rest.iterrows():
    new_line = np.zeros(400)
    words = list(row['detailed'].split(' '))
    for word in words:
        if word in dictionary:
            new_line[dictionary[word]] += 1
    test_rest_buzzword.append(new_line)

# %%
df4 = pd.DataFrame(test_rest_buzzword, columns=feature_list)

# %%
df4['goal_val'] = 0

# %%
test_tables = [df3, df4]
top_test_data = pd.concat(test_tables)

# %% [markdown]
# ---
# **saving the data frames to a .csv file:**

# %%
name = 'test_data'

path = "../data_frames/sport/" + name
print("Pathname:", path)
# Out:
# Pathname: ../data_frames/sport/test_data

# %%
top_test_data.to_csv(path, index=False)

# %% [markdown]
# ---
